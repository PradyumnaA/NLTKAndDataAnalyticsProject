# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
Importing the libraries here
"""
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dataframe=pd.read_csv("UpdatedResumeDataset.csv")
dataframe.head()
dataframe.shape
dataframe['Category'] = dataframe['Category'].astype('category')

plt.figure(figsize=(40, 60))
"""
Create a bar graph here
"""
sns.countplot(data=dataframe, x='Category')
plt.xticks(rotation=45)
plt.show()
#DND First Backup
# Out:
# C:\Users\pradc\anaconda3\envs\firstPythonEnv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\pradc\anaconda3\envs\firstPythonEnv\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
dataframe.shape
# Out:
# (962, 2)

# %%
total_count=dataframe['Category'].value_counts()
#Count the total values here
labels=dataframe['Category'].unique()
print(labels)
# Out:
# ['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing', ..., 'Hadoop', 'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing']
# Length: 25
# Categories (25, object): ['Advocate', 'Arts', 'Automation Testing', 'Blockchain', ..., 'SAP Developer', 'Sales', 'Testing', 'Web Designing']

# %%
# counts = dataframe["Category"].value_counts()
# labels = counts.index.unique().tolist()  # Convert the index to a list of labels
# sizes = counts.values.tolist()  # Convert the values to a list of sizes

# plt.pie(sizes, labels=labels, autopct='%1.1f%%',startangle=45)#Create a pie plot with start angle as f45 degreees

# plt.figure(figsize=(130, 50))#Create a pieplot with width as 130 and height as 50
# plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular
# plt.show()
counts=dataframe['Category'].value_counts()
labels=dataframe['Category'].unique()
plt.figure(figsize=(15,50))
plt.pie(counts,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2361c00d790>,
# ...
#  [Text(1.058871228953308, 0.29797939609125923, 'Data Science'),
#   Text(0.7841417468169058, 0.7714413269322118, 'HR'),
#   Text(0.4134731563409379, 1.0193330903024107, 'Advocate'),
#   Text(0.053862331076050214, 1.098680503736666, 'Arts'),
#   Text(-0.2771758554020645, 1.0645062447830609, 'Web Designing'),
#   Text(-0.5706079161115722, 0.9404289479119671, 'Mechanical Engineer'),
#   Text(-0.8089120262381768, 0.7454269473310228, 'Sales'),
#   Text(-0.9773196261993998, 0.5048230860860717, 'Health and fitness'),
#   Text(-1.0745482070561094, 0.23525762625789806, 'Civil Engineer'),
#   Text(-1.0988505454600117, -0.05027403646252011, 'Java Developer'),
#   Text(-1.0485773173407904, -0.3323937567981556, 'Business Analyst'),
#   Text(-0.9271404102234844, -0.5919549473825093, 'SAP Developer'),
#   Text(-0.7427813690411197, -0.811341998053472, 'Automation Testing'),
#   Text(-0.5207132389301881, -0.9689467079271352, 'Electrical Engineering'),
# ...

# %%
dataframe["Category"][0]
dataframe['Resume'][0]
# Out:
# 'Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details \r\n\r\nData Science Assurance Associate \r\n\r\nData Science Assurance Associate - Ernst & Young LLP\r\nSkill Details \r\nJAVASCRIPT- Exprience - 24 months\r\njQuery- Exprience - 24 months\r\nPython- Exprience - 24 monthsCompany Details \r\ncompany - Ernst & Young LLP\r\ndescription - Fraud Investigat
# ...

# %%
import re
def cleanResume(txt):
    """
    Create a resume dataset remove all the unwanted special charecters here sub stands for substitute
    """
    cleanText = re.sub('http\S+\s', ' ', txt)
    cleanText = re.sub('RT|cc', ' ', cleanText)
    cleanText = re.sub('#\S+\s', ' ', cleanText)
    cleanText = re.sub('@\S+', '  ', cleanText)  
    cleanText = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', cleanText)
    cleanText = re.sub(r'[^\x00-\x7f]', ' ', cleanText) 
    cleanText = re.sub('\s+', ' ', cleanText)
    return cleanText
someString="Immameaaaooowwww #Genius #Okau #Cokaywebsite like this http://helloword and access it okaucokayitemshouldnotrepeatba@gmail.com"
cleanResume(someString)
# Out:
# 'Immameaaaooowwww like this and a ess it okaucokayitemshouldnotrepeatba '

# %%
dataframe["Resume"]=dataframe["Resume"].apply(lambda x:cleanResume(x))

# %%
dataframe["Category"]
# Out:
# 0      Data Science
# 1      Data Science
# 2      Data Science
# 3      Data Science
# 4      Data Science
#            ...
# 957         Testing
# 958         Testing
# 959         Testing
# 960         Testing
# 961         Testing
# Name: Category, Length: 962, dtype: category
# Categories (25, object): ['Advocate', 'Arts', 'Automation Testing', 'Blockchain', ..., 'SAP Developer', 'Sales', 'Testing', 'Web Designing']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit(dataframe["Category"])
dataframe["Category"]=le.transform(dataframe["Category"])
print(dataframe["Category"])
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 957    23
# 958    23
# 959    23
# 960    23
# 961    23
# Name: Category, Length: 962, dtype: int64

# %%
"""
['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing', ..., 'Hadoop', 'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing']
Length: 25
Categories (25, object): ['Advocate', 'Arts', 'Automation Testing', 'Blockchain', ..., 'SAP Developer', 'Sales', 'Testing', 'Web Designing']
"""
# Out:
# "\n['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing', ..., 'Hadoop', 'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing']\nLength: 25\nCategories (25, object): ['Advocate', 'Arts', 'Automation Testing', 'Blockchain', ..., 'SAP Developer', 'Sales', 'Testing', 'Web Designing']\n"

# %%
dataframe.Category.unique()
# Out:
# array([ 6, 12,  0,  1, 24, 16, 22, 14,  5, 15,  4, 21,  2, 11, 18, 20,  8,
#        17, 19,  7, 13, 10,  9,  3, 23])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#Convert the words to english charecters
tfidf=TfidfVectorizer(stop_words='english' )
#Create a term frequency inverse document frequency of charecters

tfidf.fit(dataframe["Resume"])
requiredText=tfidf.transform(dataframe["Resume"])
print(requiredText)
# Out:
#   (0, 7368)	0.07791838313618284
#   (0, 7356)	0.013773935617086773
#   (0, 7303)	0.015623956436878255
#   (0, 7299)	0.08208089215094955
#   (0, 7298)	0.04529282661236908
#   (0, 7297)	0.07363448111591957
#   (0, 7152)	0.09058565322473816
#   (0, 7139)	0.03209300708360493
#   (0, 7069)	0.03563467529338486
#   (0, 7065)	0.07917736197354959
#   (0, 7052)	0.015070726656576475
#   (0, 7028)	0.04529282661236908
#   (0, 7002)	0.014495067472230672
#   (0, 6997)	0.05614419261764604
#   (0, 6995)	0.018462126900691832
#   (0, 6990)	0.02570126277514359
#   (0, 6965)	0.041040446075474774
#   (0, 6940)	0.021083158514245675
#   (0, 6939)	0.022800124584703946
#   (0, 6856)	0.04529282661236908
#   (0, 6835)	0.04529282661236908
#   (0, 6751)	0.18219672162077524
#   (0, 6750)	0.06347026993336576
#   (0, 6749)	0.09068830341053319
#   (0, 6710)	0.0340400803211732
#   :	:
#   (961, 1639)	0.0483246284265704
#   (961, 1447)	0.014243638406091599
#   (961, 1399)	0.0543835808798097
# ...

# %%
"""
Working of tfidf vectorizer
Say suppose we have sentence "Data Analytics course "
Matrix form can be given as 

|--
|1 0 0
|0 1 0
|0 0 1
Here first bit represents Data
Next is Analytics 
Another is course
|--
"""
# Out:
# '\nWorking of tfidf vectorizer\nSay suppose we have sentence "Data Analytics course "\nMatrix form can be given as \n\n|--\n|1 0 0\n|0 1 0\n|0 0 1\nHere first bit represents Data\nNext is Analytics \nAnother is course\n|--\n'

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(requiredText,dataframe['Category'],test_size=0.2,random_state=50)
X_train.shape
# Out:
# (625, 5000)

# %%
X_test.shape
# Out:
# (337, 5000)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score

# Create a KNeighborsClassifier with distance-weighted neighbors
clf = OneVsRestClassifier(KNeighborsClassifier())

# Train the classifier
clf.fit(X_train, Y_train)

# Print the classifier
print(clf)

# Make predictions on the test set
Y_Pred = clf.predict(X_test)
print(Y_Pred)
print(accuracy_score(Y_test,Y_Pred))
# Out:
# KNeighborsClassifier()
# [18  3 11  7 18  8  7  2 23 18 19  0 15 14 23  8 23  8  3  3  8 22 16 17
#   8  1  3 11 22 15  3  9 22  6 17  6 16 18  6 10 24  7 15 14 13 20 23 15
#   2 20  7 10 11  4  7  9 22 15 20  8  3 19 23 18 18 20  6  6 15 15 13  7
#  20 10 22  6  8 20 22  8 23 11 17  3  7 12 10 23  1 13 11  6  7 11 15 17
#   6  5 11 12 19 18  6 20 20 20 22  9  8 19 22 13  2 19  7  2 12 13 24 18
#  15 23  4  6  6 16  4 12 23 10  8 14  5  0 13  9 11  0 15 15 23 13  1  3
#  23 10 15 22 12  8 18 12 23 12 15 15 21  7 10  4 13 18 24  7  9 20 20 10
#   6  9  6 24  3  2 22  1 11 19 20 20 24  5  3 23 14  7 16 24 14 15 15  3
#  14 15 13 19 11  2 23  3 12 14 14 20 15 23 11 18  6 20  6 22  8  1 11 23
#  15  2  4  2  8  2 16 20  7 16 22 15  6 17 15  7 12 15  1 16 14 11 16 10
#  11 20  7 15 15  8 14 10 24  6  8 22 21  9 24  9  9  5 16  7 15 16 15 15
#  23 20 24 23 18 17 17  8 20 15 14 13 15  3 16  6  1 12 15 22  7 20  4 11
#   6 19 23  3  1 18 15 21 16 23  5 17  8 24 23 22  2  3 13 15 14  2  9  0
# ...

# %%
import pickle
pickle.dump(tfidf,open('tfidf.pkl','wb'))
pickle.dump(clf,open('clf.pkl','wb'))

# %%
myresume="""

VIJETH
145 W Pine St, Stockton, CA 95204 | vijethm1@gmail.com | +1-209-937-2585 | https://www.linkedin.com/in/vijeth-melugiriyappa/


EDUCATION:
University of the Pacific, CA									Aug,2022 – Present
Master of Science, Computer Science 
Course Work: UX Design, Advanced Data Analytics, DBMS with SQL, Computational Biology with Machine Learning, Computer Network Security, System Security
Visvesvaraya Technological University, KA, India						Aug,2015 – May,2019

WORK EXPERIENCE:
Graduate Teaching Assistant									Jan,2023 - Present
•	Strong understanding of research techniques, methodologies, and tools relevant to latest Computer Science technologies such as Cloud Computing, Machine Learning, Artificial Intelligence.
•	Experience in leading or assisting with lectures, discussions, and labs related to research techniques.
•	Proficiency in assisting students with literature reviews, research design, data collection, and analysis.
Software Engineer, Mphasis, India								Sep,2019 – Aug,2022
•	Developed code to migrate the token authorization system for SSO login from CSK to OAuth tokens for a brokerage application.
•	Played a major role in developing web services for Asset Management using Spring Boot and Microservice architecture.
•	Developed a Low-level System Design of Client brokerage Applications for load balancing in UAT region.
•	Created Restore and Backup jobs for Databases and AWS Environment.
•	Responsible for migrating data from Oracle to MongoDB in a short period of time.
•	Migrated dependent services from SOAP to RESTful for superior performance of the banking application.
•	Solely analyzed the widespread Log4j vulnerability and worked with the security team to pull out the possible threats. 
•	Automated continuous integration and deployment of the code in Prod region using Jenkins.
•	Strong experience in working under Agile and Scrum Environments.

TECHNICAL SKILLS:
•	Languages: Java, Python, C
•	Tools/Libraries: AWS, Core Java, Spring Boot, Spring MVC, Hibernate, Kafka, Kubernetes, RabbitMq, Log4J, Jenkins, Bitbucket, JUnit, Mockito
•	Database: MySQL, Oracle, MongoDb, Elastic Search
•	Web Technologies: Struts, Angular 8

PROJECTS:
•	Efficient and Secure Cloud Log Secrecy Scheme: Built a responsive web application to generate and secure cloud logs, encrypting the user credentials with RSA- KEM. Generated proof of past logs, which helped to prevent log tampering in public clouds.
•	Hotel Review- Sentiment Analysis: Used a Perceptron and Naive Bayes model to predict the sentiment of hotel reviews, and after applying Laplace smoothing, the models produced F1 scores of 90.4% and 91.4%, respectively.
•	BuzzMovies: A web-based application for online movie rental using Spring, MongoDb & Angular framework.


"""
print(myresume)
# Out:
# VIJETH
# 145 W Pine St, Stockton, CA 95204 | vijethm1@gmail.com | +1-209-937-2585 | https://www.linkedin.com/in/vijeth-melugiriyappa/
#
#
# EDUCATION:
# University of the Pacific, CA									Aug,2022 – Present
# Master of Science, Computer Science
# Course Work: UX Design, Advanced Data Analytics, DBMS with SQL, Computational Biology with Machine Learning, Computer Network Security, System Security
# Visvesvaraya Technological University, KA, India						Aug,2015 – May,2019
#
# WORK EXPERIENCE:
# Graduate Teaching Assistant									Jan,2023 - Present
# •	Strong understanding of research techniques, methodologies, and tools relevant to latest Computer Science technologies such as Cloud Computing, Machine Learning, Artificial Intelligence.
# •	Experience in leading or assisting with lectures, discussions, and labs related to research techniques.
# •	Proficiency in assisting students with literature reviews, research design, data collection, and analysis.
# ...

# %%
import pickle
clf=pickle.load(open('clf.pkl','rb'))
cleaned_resume=cleanResume(myresume)
input_features=tfidf.transform([cleaned_resume])
prediction_id=clf.predict(input_features)[0]
print(prediction_id)
category_mapping = {
    15: "Java Developer",
    23: "Testing",
    8: "DevOps Engineer",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "ETL Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate",
}
#remember the line after df.Category.unique() there is an array with numbers and categories
category_name=category_mapping.get(prediction_id,"Unknown")
print("Predicted Category:",category_name)
print(prediction_id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 5
#       3 cleaned_resume=cleanResume(myresume)
#       4 input_features=tfidf.transform([cleaned_resume])
# ----> 5 prediction_id=clf.predict(input_features)
#       6 print(prediction_id)
#       7 category_mapping = {
#       8     15: "Java Developer",
#       9     23: "Testing",
#    (...)
#      32     0: "Advocate",
#      33 }
#
# File ~\anaconda3\envs\firstPythonEnv\Lib\site-packages\sklearn\neighbors\_classification.py:266, in KNeighborsClassifier.predict(self, X)
#     263         return self.classes_[np.argmax(probabilities, axis=1)]
#     264     # In that case, we do not need the distances to perform
#     265     # the weighting so we do not compute them.
# --> 266     neigh_ind = self.kneighbors(X, return_distance=False)
#     267     neigh_dist = None
#     268 else:
#
# ...
